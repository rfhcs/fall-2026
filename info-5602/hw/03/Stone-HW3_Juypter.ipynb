# %% [markdown]
# # Homework 3: (Part 3)
#
# Instructions:
#
# 1. Include your name and student ID in the placeholders below
#
# 2. Follow the prompts (i.e. text beginning with #) in each cell to answer each question
#
# 3. Start your homework by running the code from the beginning of the homework i.e. the Setup Sections
#
# 4. You can try to confirm your answer by running each cell
#
# 5. Remember each question is for/worth one (1) point
#
# 6. Remember to SAVE YOUR WORK
#
# 7. Upload your completed Jupyter notebook to Canvas before or on the due date
#
#
# Note the following:
#
# =   means "equal to"
#
# < = means " less than or equal to"

# %% [markdown]
# # Add your student details below
#
# Student Name: Rey Stone
#
# Student ID: 111044637

# %%
#Setup Section 1.0: Run this cell before you attempt Questions 1 - 10 and before any other Setup Section cells below.


#Loading Matplotlib and Seaborn

from matplotlib import pyplot as plt
import seaborn as sns

#Load mpg dataset

cars = sns.load_dataset('mpg').dropna()

#Load penguins dataset

penguins = sns.load_dataset('penguins').dropna()


#The code below draws a KDE plot for the body_mass_g variable/feature in the penguins dataframe.


sns.kdeplot(penguins.body_mass_g, fill=False)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
#Question 1:

#Consider the KDE for body_mass_g above.

#Does the KDE plot for body_mass_g suggest it is a perfectly normally distributed variable? YES or NO?

#Write your answer below:

#NO

# %%
#Question 2:

#Explain your answer to Question 1.


#Write your answer below:

#I don't think it is a perfectly normally distributed variable, because while it kind of mirrors itself, the peak of the distribution does not look like it sits around the average. From eye-balling this, the mean seems to sit around the middle.

# %%
#Setup Section 1.1: Run this cell before you attempt Questions 3 - 4


#The code below draws the KDE plot for the flipper_length_mm feature in the penguins dataframe

sns.kdeplot(penguins.flipper_length_mm, fill=False)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
#Question 3: 

#A friend argues that the variable flipper_length_mm is NOT normally distributed. Do you agree? YES or NO?

#Write your answer below:

#YES, it is not normally distributed.

# %%
#Question 4:

#Explain your answer to Question 3 above.

#Write your answer below:

#This chart is NOT normally distributed because it peaks in two separate locations instead of just one. A normal distribution only has one peak and two tails.

# %%
#Setup Section 1.2: Run this cell before you attempt Questions 5 - 6

#The code below draws the KDE plot for the displacement feature in the cars dataframe.

sns.kdeplot(cars.displacement, fill=False)
# Out:
# <Axes: xlabel='displacement', ylabel='Density'>

# %%
#Question 5:

#The area under the KDE for the numerical variable displacement represents 100% of all the observations for the variable.

#Would you argue that the bulk of the observations for displacement are between 300 and 500? YES or NO?

#Write your answer below:

#NO, I would argue that the bulk of observations lie between 0 and 200, because that's where the curve peaks the most.

# %%
#Question 6:

#Write one insight that is clear about observations below 200.


#Write your answer below:

#There is a high density of displacement below 200.

# %%
#Setup Section 1.3: Run this cell before you attempt Questions 7 - 11

#The code below draws a univariate Displot for the horsepower feature in the cars dataframe, and
#1. breakouts/conditions the Displot by/on the origin feature
#2. facets the chart by origin

sns.displot(x=cars.horsepower,  hue=cars.origin, col=cars.origin)

# %%
#Question 7:

#Consider the chart from Setup Section 1.3 above. Which of the following is/are arguably true?

#Select all that apply.

#1. numerical variable horsepower does not appear to be a normally distributed variable, especially when origin = usa
#2. the bulk of observations for horsepower exist where origin = usa
#3. the bulk of observations for horsepower exist where origin = europe


#Write your answer below:

#The following statements are arguably true:
#1. numerical variable horsepower does not appear to be a normally distributed variable, especially when origin = usa
#2. the bulk of observations for horsepower exist where origin = usa

# %%
#Question 8:

#Lets define horsepower as "the power of the engine of a car"

#Write one insight that can be seen in the chart from Setup Section 1.3 above when origin = usa and horsepower < = 100.


#Write your answer below:

#A majority of cars with origin = europe have horsepower <= 100.

# %%
#Question 9:

#Lets define horsepower as "the power of the engine of a car"

#Write one insight that can be seen in the chart from Setup Section 1.3 above when origin = europe and horsepower > 150.


#Write your answer below:

#There are NO CARS with horsepowers > 150 in europe. This makes the chart skewed right (positive skew).

# %%
#Question 10:

#Lets define horsepower as "the power of the engine of a car"

#Overall, would you argue that when origin = japan, horsepower has the most observations? YES or NO?


#Write your answer below:

#NO. I would argue that when origin = usa, horsepower has the most observations.

# %%
#Question 11:


#Consider when:

#origin = japan and 
#origin = europe. 

#What is true of the dataframe when the value of horsepower is greater than 150 

#Write your answer below:


#When horsepower > 150, and origin = japan and origin = europe NO COUNT OF CARS EXIST. Meaning there are no cars with origin = japan and origin = europe that exist.

# %%
#Setup Section 2.0: Run this cell before you attempt Questions 12 - 20 and before any other Setup Section cells below.


#Import pandas as we try to create a Pandas Data Framne that contains the data

import pandas as pd

#Import Matplotlib and Seaborn
from matplotlib import pyplot as plt
import seaborn as sns

# load dataset from the Web
url = 'https://vincentarelbundock.github.io/Rdatasets/csv/AER/USGasG.csv'
USG = pd.read_csv(url,index_col=0).dropna()

#create a subset of USG data frame (call the dataframe USG_Subset) 
#with/including only the features gas, price,income,service, population
USG_Subset = USG[["gas","price","income","service","population"]]

#Display first few rows of USG_subset
USG_Subset.head(10)
# Out:
#             gas  price  income  service  population
# rownames
# 1         129.7  0.925    6036    0.302       180.7
# 2         131.3  0.914    6113    0.307       183.7
# 3         137.1  0.919    6271    0.314       186.5
# 4         141.6  0.918    6378    0.320       189.2
# 5         148.8  0.914    6727    0.325       191.9
# 6         155.9  0.949    7027    0.332       194.3
# 7         164.9  0.970    7280    0.342       196.6
# 8         171.0  1.000    7513    0.353       198.7
# 9         183.4  1.014    7728    0.368       200.7
# 10        195.8  1.047    7891    0.386       202.7

# %%
#Setup Section 2.1: Run the code below before you attempt Questions 12 - 15

#The code below presents summary statistics for the USG_Subset dataframe

USG_Subset.describe().T


#Note the names of the variables
# Out:
#             count         mean          std       min         25%        50%  \
# gas          36.0   226.094444    50.591817   129.700   192.70000   235.1500
# price        36.0     2.316611     1.251735     0.914     1.03875     1.9225
# income       36.0  9232.861111  1786.380845  6036.000  7850.25000  9551.5000
# service      36.0     0.836250     0.496515     0.302     0.38150     0.6730
# population   36.0   221.947222    24.008385   180.700   202.20000   221.4000
#
#                     75%        max
# gas           270.00000    297.800
# price           3.71775      4.109
# income      10799.75000  11934.000
# service         1.23575      1.786
# population    241.22500    263.200

# %%
USG_Subset.describe().T['75%'].max()
# Out:
# np.float64(10799.75)

# %%
#Question 12: 

#Which of the numerical variables has the largest 75th percentile?


#Write your answer below:


#INCOME has the largest 75th percentile which is 10799.75

# %%
USG_Subset.describe().T['min'].min()
# Out:
# np.float64(0.302)

# %%
#Question 13:

#Which of the variables has the smallest minimum value?

#Write your answer below:

#SERVICE has the smallest minimum value with the value being 0.302

# %%
values = USG_Subset

iqr_list = []

for col in values:
    q1 = values[col].quantile(0.25)
    q3 = values[col].quantile(0.75)

    iqr = q3-q1

    iqr_list.append(iqr)

    print(col)
    print(f"Q1: {q1}, Q3: {q3}, IQR: {iqr}")

print("Smallest IQR", min(iqr_list))
# Out:
# gas
# Q1: 192.70000000000002, Q3: 270.0, IQR: 77.29999999999998
# price
# Q1: 1.0387499999999998, Q3: 3.71775, IQR: 2.6790000000000003
# income
# Q1: 7850.25, Q3: 10799.75, IQR: 2949.5
# service
# Q1: 0.3815, Q3: 1.23575, IQR: 0.85425
# population
# Q1: 202.2, Q3: 241.225, IQR: 39.025000000000006
# Smallest IQR 0.85425

# %%
#Question 14:

#Which of the variables has the smallest Interquartile range (IQR)?


#Write your answer below:

#SERVICE has the smallest interquartile range with it being 0.85

# %%
USG_Subset['price'].var() / 100
# Out:
# np.float64(0.015668395587301584)

# %%
#Question 15:

#What is the numerical result of dividing the variance of price by 100?

#Round your answer to 2 decimal places.


#Write your answer below:

#When diving the variance of PRICE by 100 I get 0.015

# %%
#Setup Section 2.2: Run the code below before you attempt Questions 16 - 20

#The code presents the correlation matrix for the USG_Subset dataframe

USG_Subset.corr()


#Note the names of the variables
# Out:
#                  gas     price    income   service  population
# gas         1.000000  0.769657  0.975365  0.853434    0.944217
# price       0.769657  1.000000  0.877395  0.898388    0.905520
# income      0.975365  0.877395  1.000000  0.930821    0.989222
# service     0.853434  0.898388  0.930821  1.000000    0.968719
# population  0.944217  0.905520  0.989222  0.968719    1.000000

# %%
USG_Subset['price'].corr(USG_Subset['gas'])
# Out:
# np.float64(0.76965725285122)

# %%
#Question 16:

#Are price and gas negatively correlated? YES or NO?


#Write your answer below:

#NO, they are almost not correlated at all.

# %%
print(USG_Subset['income'].corr(USG_Subset['gas']))
print(USG_Subset['service'].corr(USG_Subset['population']))
print(USG_Subset['income'].corr(USG_Subset['income']))
# Out:
# 0.97536473959386
# 0.9687194107853467
# 1.0

# %%
#Question 17:

#Which of the following pairs of variables has the strongest correlation between them?

#income-gas
#service-population
#income-income

#Write your answer below:

#The strongest correlation is income-income, but that's kind of an unfair comparison because we are just comparing it to itself. The second strongest is income-gas.

# %%
gas_gas = USG_Subset['gas'].corr(USG_Subset['gas'])
gas_pop = USG_Subset['gas'].corr(USG_Subset['population'])

print(gas_gas / gas_pop)
# Out:
# 1.0590788301087244

# %%
#Question 18:

#What is the numerical result of dividing the correlation between gas and gas with the correlation between gas and population?

#Round your answer to 2 decimal places

#Write your answer below:

#The numerical result is 1.06 (rounded to the nearest hundredth)

# %%
gas_pop
# Out:
# np.float64(0.9442167774209409)

# %%
#Question 19:

#Can you claim that gas and population have a positively statistically significant relationship? YES or NO?

#Write your answer below:

#I can claim that gas and population have a positive correlation, and therefore can conclude that gas and population do have a statistically significant relationship.

# %%
gas_price = USG_Subset['gas'].corr(USG_Subset['price'])
service_income = USG_Subset['service'].corr(USG_Subset['income'])

print(gas_price, service_income)
print(service_income - gas_price)
# Out:
# 0.7696572528512199 0.9308211092652765
# 0.16116385641405662

# %%
#Question 20: 

#What is the difference between the correlation between gas and price and the correlation between
#service and income?


#Write your answer below:

# I honestly can't tell if you are asking for the "difference" (subtraction) or "difference" meaning how the correlation differs, so I'll give both:
# Difference (gas_income - gas_price) = 0.16
# Difference (how correlation differs): The correlation between service-income is a lot stronger than gas_price.
# Thus we can conclude that the correlation between service-income is stronger than gas and price.

# %%
# *****************************************End of Homework***********************************************************
